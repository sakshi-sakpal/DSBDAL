# %%
import pandas as pd
import numpy as np

# %%
dt=pd.read_csv('salary.csv')

# %%
dt
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
dt.isnull()
# Out:
#          age  workclass  fnlwgt  education  education-num  marital-status  \
# 0      False      False   False      False          False           False
# 1      False      False   False      False          False           False
# 2      False      False   False      False          False           False
# 3      False      False   False      False          False           False
# 4      False      False   False      False          False           False
# ...      ...        ...     ...        ...            ...             ...
# 32556  False      False   False      False          False           False
# 32557  False      False   False      False          False           False
# 32558  False      False   False      False          False           False
# 32559  False      False   False      False          False           False
# 32560  False      False   False      False          False           False
#
#        occupation  relationship   race    sex  capital-gain  capital-loss  \
# ...

# %%
dt.isnull
# Out:
# <bound method DataFrame.isnull of        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# ...

# %%
dt.shape
# Out:
# (32561, 15)

# %%
dt.fillna(dt.mode().iloc[0], inplace=True)

# %%
print(dt.isnull().sum())
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
dt.fillna(dt.mode().iloc[1], inplace=True)

# %%
dt.fillna(dt.mode().iloc[2], inplace=True)

# %%
dt.replace("?", np.nan, inplace=True)

# %%
dt.fillna(dt.mode().iloc[0], inplace=True)

# %%
dt
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
dt.replace({"?": np.nan}, inplace=True)

# %%
dt.fillna(dt.mode(), inplace=True)

# %%
print((dt == "?").sum())  # Shows how many "?" are present in each column
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
dt
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
dt.iloc[70:71, 0:2]
# Out:
#     age workclass
# 70   19   Private

# %%
dt.isnull
# Out:
# <bound method DataFrame.isnull of        age          workclass  fnlwgt    education  education-num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# ...

# %%
dt["workclass"] = dt["workclass"].replace(to_replace=r".*gov.*", value="Government", regex=True)

# %%
dt
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39         Government   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
dt
# Out:
#        age          workclass  fnlwgt    education  education-num  \
# 0       39         Government   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
dt["workclass"] = dt["workclass"].replace(to_replace="Government", value="Public", regex=True)

# %%
dt["education"] = dt["education"].str.strip()  # Remove extra spaces
dt["education"] = dt["education"].replace({"11th": "HS-grad", "12th": "HS-grad"})

# %%
dt
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39             Public   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721     HS-grad              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 32556   27            Private  257302  Assoc-acdm             12
# 32557   40            Private  154374     HS-grad              9
# 32558   58            Private  151910     HS-grad              9
# 32559   22            Private  201490     HS-grad              9
# 32560   52       Self-emp-inc  287927     HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
dt["workclass"] = dt["workclass"].replace(to_replace=r".*Self.*", value="Private", regex=True)

# %%
print(dt["education"].unique())  # Check if "11th" and "12th" are replaced
# Out:
# ['Bachelors' 'HS-grad' 'Masters' '9th' 'Some-college' 'Assoc-acdm'
#  'Assoc-voc' '7th-8th' 'Doctorate' 'Prof-school' '5th-6th' '10th'
#  '1st-4th' 'Preschool']

# %%
dt["education"] = dt["education"].apply(lambda x: "Middle School" if x in ["6th", "7th", "8th"] else x)

# %%
dt
# Out:
#        age workclass  fnlwgt   education  education-num       marital-status  \
# 0       39    Public   77516   Bachelors             13        Never-married
# 1       50   Private   83311   Bachelors             13   Married-civ-spouse
# 2       38   Private  215646     HS-grad              9             Divorced
# 3       53   Private  234721     HS-grad              7   Married-civ-spouse
# 4       28   Private  338409   Bachelors             13   Married-civ-spouse
# ...    ...       ...     ...         ...            ...                  ...
# 32556   27   Private  257302  Assoc-acdm             12   Married-civ-spouse
# 32557   40   Private  154374     HS-grad              9   Married-civ-spouse
# 32558   58   Private  151910     HS-grad              9              Widowed
# 32559   22   Private  201490     HS-grad              9        Never-married
# 32560   52   Private  287927     HS-grad              9   Married-civ-spouse
#
# ...

# %%
print(dt["education"].value_counts())  # Check if replacements happened
# Out:
# HS-grad         12109
# Some-college     7291
# Bachelors        5355
# Masters          1723
# Assoc-voc        1382
# Assoc-acdm       1067
# 10th              933
# 7th-8th           646
# Prof-school       576
# 9th               514
# Doctorate         413
# 5th-6th           333
# 1st-4th           168
# Preschool          51
# Name: education, dtype: int64

# %%
dt['education'] = dt['education'].replace(['1st-4th'], 'Primary School')

# %%
print(dt["education"].value_counts())
# Out:
# HS-grad           12109
# Some-college       7291
# Bachelors          5355
# Masters            1723
# Assoc-voc          1382
# Assoc-acdm         1067
# 10th                933
# 7th-8th             646
# Prof-school         576
# 9th                 514
# Doctorate           413
# 5th-6th             333
# Primary School      168
# Preschool            51
# Name: education, dtype: int64

# %%
print(dt["education"].value_counts())
# Out:
# HS-grad           12109
# Some-college       7291
# Bachelors          5355
# Masters            1723
# Assoc-voc          1382
# Assoc-acdm         1067
# 10th                933
# 7th-8th             646
# Prof-school         576
# 9th                 514
# Doctorate           413
# 5th-6th             333
# Primary School      168
# Preschool            51
# Name: education, dtype: int64

# %%
dt['education'] = dt['education'].replace(['5th-6th'], 'Primary School')

# %%
dt
# Out:
#        age workclass  fnlwgt   education  education-num       marital-status  \
# 0       39    Public   77516   Bachelors             13        Never-married
# 1       50   Private   83311   Bachelors             13   Married-civ-spouse
# 2       38   Private  215646     HS-grad              9             Divorced
# 3       53   Private  234721     HS-grad              7   Married-civ-spouse
# 4       28   Private  338409   Bachelors             13   Married-civ-spouse
# ...    ...       ...     ...         ...            ...                  ...
# 32556   27   Private  257302  Assoc-acdm             12   Married-civ-spouse
# 32557   40   Private  154374     HS-grad              9   Married-civ-spouse
# 32558   58   Private  151910     HS-grad              9              Widowed
# 32559   22   Private  201490     HS-grad              9        Never-married
# 32560   52   Private  287927     HS-grad              9   Married-civ-spouse
#
# ...

# %%
print(dt["education"].value_counts())
# Out:
# HS-grad           12109
# Some-college       7291
# Bachelors          5355
# Masters            1723
# Assoc-voc          1382
# Assoc-acdm         1067
# 10th                933
# 7th-8th             646
# Prof-school         576
# 9th                 514
# Primary School      501
# Doctorate           413
# Preschool            51
# Name: education, dtype: int64

# %%
dt['education'] = dt['education'].replace(['7th-8th'], 'secondary School')

# %%
dt
# Out:
#        age workclass  fnlwgt   education  education-num       marital-status  \
# 0       39    Public   77516   Bachelors             13        Never-married
# 1       50   Private   83311   Bachelors             13   Married-civ-spouse
# 2       38   Private  215646     HS-grad              9             Divorced
# 3       53   Private  234721     HS-grad              7   Married-civ-spouse
# 4       28   Private  338409   Bachelors             13   Married-civ-spouse
# ...    ...       ...     ...         ...            ...                  ...
# 32556   27   Private  257302  Assoc-acdm             12   Married-civ-spouse
# 32557   40   Private  154374     HS-grad              9   Married-civ-spouse
# 32558   58   Private  151910     HS-grad              9              Widowed
# 32559   22   Private  201490     HS-grad              9        Never-married
# 32560   52   Private  287927     HS-grad              9   Married-civ-spouse
#
# ...

# %%
print(dt["education"].value_counts())
# Out:
# HS-grad             12109
# Some-college         7291
# Bachelors            5355
# Masters              1723
# Assoc-voc            1382
# Assoc-acdm           1067
# 10th                  933
# secondary School      646
# Prof-school           576
# 9th                   514
# Primary School        501
# Doctorate             413
# Preschool              51
# Name: education, dtype: int64

# %%
dt['education'] = dt['education'].replace(['9th'], 'secondary School')

# %%
print(dt["education"].value_counts())
# Out:
# HS-grad             12109
# Some-college         7291
# Bachelors            5355
# Masters              1723
# Assoc-voc            1382
# secondary School     1160
# Assoc-acdm           1067
# 10th                  933
# Prof-school           576
# Primary School        501
# Doctorate             413
# Preschool              51
# Name: education, dtype: int64

# %%
dt['education'] = dt['education'].replace(['10th'], 'secondary School')

# %%
print(dt["education"].value_counts())
# Out:
# HS-grad             12109
# Some-college         7291
# Bachelors            5355
# secondary School     2093
# Masters              1723
# Assoc-voc            1382
# Assoc-acdm           1067
# Prof-school           576
# Primary School        501
# Doctorate             413
# Preschool              51
# Name: education, dtype: int64

# %%
dt['education'] = dt['education'].replace(['Some-college'], 'Bachelors')

# %%
dt['education'] = dt['education'].replace(['Assoc-voc','Assoc-acdm'], 'deploma')

# %%
dt['marital-status'] = dt['marital-status'].replace([' Never-married'], 'Unmarried')

# %%
dt['marital-status'] = dt['marital-status'].replace([' Married-civ-spouse'], 'Married')

# %%
dt['native-country'] = dt['native-country'].replace([' Married-civ-spouse'], 'Married')native-country

# %%
dt['native-country'] = dt['native-country'].replace('?', np.nan)
dt['native-country'].fillna(dt['native-country'].mode()[0], inplace=True)

# %%
dt
# Out:
#        age workclass  fnlwgt  education  education-num marital-status  \
# 0       39    Public   77516  Bachelors             13      Unmarried
# 1       50   Private   83311  Bachelors             13        Married
# 2       38   Private  215646    HS-grad              9       Divorced
# 3       53   Private  234721    HS-grad              7        Married
# 4       28   Private  338409  Bachelors             13        Married
# ...    ...       ...     ...        ...            ...            ...
# 32556   27   Private  257302    deploma             12        Married
# 32557   40   Private  154374    HS-grad              9        Married
# 32558   58   Private  151910    HS-grad              9        Widowed
# 32559   22   Private  201490    HS-grad              9      Unmarried
# 32560   52   Private  287927    HS-grad              9        Married
#
#                occupation    relationship    race      sex  capital-gain  \
# ...

# %%
print(dt.isna().sum())
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
dt['occupation'] = dt['occupation'].replace('?', np.nan)
dt['occupation'].fillna(dt['occupation'].mode()[0], inplace=True)

# %%
dt['occupation']
# Out:
# 0              Adm-clerical
# 1           Exec-managerial
# 2         Handlers-cleaners
# 3         Handlers-cleaners
# 4            Prof-specialty
#                 ...
# 32556          Tech-support
# 32557     Machine-op-inspct
# 32558          Adm-clerical
# 32559          Adm-clerical
# 32560       Exec-managerial
# Name: occupation, Length: 32561, dtype: object
